# %%
## This project is about to check car prices with respect to different variables like highway milage, engine size, 
#### and car brands etc.

### import pandas and numpy
import pandas as pd

import numpy as np

# import data set from a csv file

df= pd.read_csv(r"C:\Users\47462\Desktop\CarPrice_Assignment.csv")

#showing the first 10 columns of dataset

df.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
####checking summary information about our dataset

df.info()

## investigating summary stat. of dataframe

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
## checking something specific in the dataset
### for example we wish to find the name of car and price in 7th row

df.iloc[7][2] 

df.iloc[7][25]
# Out:
# 18920.0

# %%
# The columns attribute returns an Index object containing the dataframe's columns.
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
# You can select a column by name using brackets.
df['CarName']
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
#                  ...
# 200             volvo 145e (sw)
# 201                 volvo 144ea
# 202                 volvo 244dl
# 203                   volvo 246
# 204                 volvo 264gl
# Name: CarName, Length: 205, dtype: object

# %%
#The shape attribute returns the shape of the dataframe (rows, columns).
df.shape
# Out:
# (205, 26)

# %%
# extract data from dataset, which we need to use for further analysis

new_df=df[['CarName','enginetype','enginesize','highwaympg','price']]
new_df
# Out:
#                       CarName enginetype  enginesize  highwaympg    price
# 0          alfa-romero giulia       dohc         130          27  13495.0
# 1         alfa-romero stelvio       dohc         130          27  16500.0
# 2    alfa-romero Quadrifoglio       ohcv         152          26  16500.0
# 3                 audi 100 ls        ohc         109          30  13950.0
# 4                  audi 100ls        ohc         136          22  17450.0
# ..                        ...        ...         ...         ...      ...
# 200           volvo 145e (sw)        ohc         141          28  16845.0
# 201               volvo 144ea        ohc         141          25  19045.0
# 202               volvo 244dl       ohcv         173          23  21485.0
# 203                 volvo 246        ohc         145          27  22470.0
# 204               volvo 264gl        ohc         141          25  22625.0
#
# [205 rows x 5 columns]

# %%
## finding how many cars have highway milage less than 25mils. 
mask =df['highwaympg']<25
mask.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: highwaympg, dtype: bool

# %%
# sorting data according to highwaympg from maximum to minimum.

new_df_sort=new_df.sort_values(by='highwaympg',ascending=False)

new_df_sort.head(10)
# Out:
#                    CarName enginetype  enginesize  highwaympg   price
# 30             honda civic        ohc          92          54  6479.0
# 18        chevrolet impala          l          61          53  5151.0
# 90             nissan gt-r        ohc         103          50  7099.0
# 160          toyota corona        ohc          98          47  7738.0
# 159         toyota corolla        ohc         110          47  7788.0
# 182       vokswagen rabbit        ohc          97          46  7775.0
# 184   volkswagen model 111        ohc          97          46  7995.0
# 44            isuzu D-Max         ohc          90          43  8916.5
# 20     chevrolet vega 2300        ohc          90          43  6575.0
# 19   chevrolet monte carlo        ohc          90          43  6295.0

# %%
# Sort the data by price and print the top 20 values

newdf_sort= new_df.sort_values(['price'],ascending=False)['price']

newdf_sort.head(20)
# Out:
# 74     45400.0
# 16     41315.0
# 73     40960.0
# 128    37028.0
# 17     36880.0
# 49     36000.0
# 48     35550.0
# 72     35056.0
# 71     34184.0
# 127    34028.0
# 126    32528.0
# 47     32250.0
# 70     31600.0
# 129    31400.5
# 15     30760.0
# 68     28248.0
# 69     28176.0
# 67     25552.0
# 14     24565.0
# 8      23875.0
# Name: price, dtype: float64

# %%
#similarly sorting the ddate by price and printing bottom 20 values

newdf_sort.tail(20)
# Out:
# 20     6575.0
# 33     6529.0
# 152    6488.0
# 30     6479.0
# 22     6377.0
# 151    6338.0
# 19     6295.0
# 120    6229.0
# 24     6229.0
# 77     6189.0
# 51     6095.0
# 118    5572.0
# 21     5572.0
# 89     5499.0
# 32     5399.0
# 76     5389.0
# 150    5348.0
# 50     5195.0
# 18     5151.0
# 138    5118.0
# Name: price, dtype: float64

# %%
# investigating how many kind of cars in the dataset
new_df['CarName'].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
#average car price 
avg_carprice=new_df['price'].mean()
avg_carprice.round(2)
# Out:
# 13276.71
